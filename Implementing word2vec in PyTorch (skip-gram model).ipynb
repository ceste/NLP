# %% [markdown]
# - https://towardsdatascience.com/implementing-word2vec-in-pytorch-skip-gram-model-e6bae040d2fb

# %%
import torch
from torch.autograd import Variable
import numpy as np
import torch.functional as F
import torch.nn.functional as F

# %% [markdown]
# # Prerequisites

# %% [markdown]
# ## Corpus

# %%
corpus = [
    'he is a king',
    'she is a queen',
    'he is a man',
    'she is a woman',
    'warsaw is poland capital',
    'berlin is germany capital',
    'paris is france capital',
    'I live in Jakarta, Indonesia',
]

# %% [markdown]
# ## Creating vocabulary

# %%
def tokenize_corpus(corpus):
    tokens = [x.split() for x in corpus]
    return tokens

tokenized_corpus = tokenize_corpus(corpus)
print(tokenized_corpus)
# Out:
# [['he', 'is', 'a', 'king'], ['she', 'is', 'a', 'queen'], ['he', 'is', 'a', 'man'], ['she', 'is', 'a', 'woman'], ['warsaw', 'is', 'poland', 'capital'], ['berlin', 'is', 'germany', 'capital'], ['paris', 'is', 'france', 'capital'], ['I', 'live', 'in', 'Jakarta,', 'Indonesia']]

# %%
vocabulary = []
for sentence in tokenized_corpus:
    for token in sentence:
        if token not in vocabulary:
            vocabulary.append(token)

word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
print(vocabulary)
print()
print(word2idx)
print()
print(idx2word)
print()
print(vocabulary_size)
# Out:
# ['he', 'is', 'a', 'king', 'she', 'queen', 'man', 'woman', 'warsaw', 'poland', 'capital', 'berlin', 'germany', 'paris', 'france', 'I', 'live', 'in', 'Jakarta,', 'Indonesia']
#
# {'he': 0, 'is': 1, 'a': 2, 'king': 3, 'she': 4, 'queen': 5, 'man': 6, 'woman': 7, 'warsaw': 8, 'poland': 9, 'capital': 10, 'berlin': 11, 'germany': 12, 'paris': 13, 'france': 14, 'I': 15, 'live': 16, 'in': 17, 'Jakarta,': 18, 'Indonesia': 19}
#
# {0: 'he', 1: 'is', 2: 'a', 3: 'king', 4: 'she', 5: 'queen', 6: 'man', 7: 'woman', 8: 'warsaw', 9: 'poland', 10: 'capital', 11: 'berlin', 12: 'germany', 13: 'paris', 14: 'france', 15: 'I', 16: 'live', 17: 'in', 18: 'Jakarta,', 19: 'Indonesia'}
#
# 20

# %%
word2idx['I'], word2idx['live'], word2idx['in'], word2idx['Jakarta,'], word2idx['Indonesia']
# Out:
# (15, 16, 17, 18, 19)

# %%
window_size = 2
idx_pairs = []
# for each sentence
for sentence in tokenized_corpus:
    print('sentence:',sentence)
    indices = [word2idx[word] for word in sentence]
    print('indices:',indices)
    # for each word, threated as center word    
    print(range(len(indices)))
    print()
    for center_word_pos in range(len(indices)):
        print('center_word_pos:',center_word_pos)
        # for each window position
        print(range(-window_size, window_size + 1))
        print()
        for w in range(-window_size, window_size + 1):                    
            context_word_pos = center_word_pos + w
            print('context_word_pos:',context_word_pos,'w:',w)
            # make soure not jump out sentence
            if context_word_pos < 0 or context_word_pos >= len(indices) or center_word_pos == context_word_pos:
                continue
            print('in')
            context_word_idx = indices[context_word_pos]
            print('context_word_idx:',context_word_idx,indices[context_word_pos])
            print('xx:',(indices[center_word_pos], context_word_idx))
            idx_pairs.append((indices[center_word_pos], context_word_idx))
        print()

idx_pairs = np.array(idx_pairs) # it will be useful to have this as numpy array
# Out:
# sentence: ['he', 'is', 'a', 'king']
# indices: [0, 1, 2, 3]
# range(0, 4)
#
# center_word_pos: 0
# range(-2, 3)
#
# context_word_pos: -2 w: -2
# context_word_pos: -1 w: -1
# context_word_pos: 0 w: 0
# context_word_pos: 1 w: 1
# in
# context_word_idx: 1 1
# xx: (0, 1)
# context_word_pos: 2 w: 2
# in
# context_word_idx: 2 2
# xx: (0, 2)
#
# center_word_pos: 1
# range(-2, 3)
#
# context_word_pos: -1 w: -2
# context_word_pos: 0 w: -1
# in
# context_word_idx: 0 0
# xx: (1, 0)
# context_word_pos: 1 w: 0
# context_word_pos: 2 w: 1
# in
# context_word_idx: 2 2
# xx: (1, 2)
# context_word_pos: 3 w: 2
# in
# context_word_idx: 3 3
# xx: (1, 3)
#
# center_word_pos: 2
# range(-2, 3)
#
# context_word_pos: 0 w: -2
# in
# context_word_idx: 0 0
# xx: (2, 0)
# context_word_pos: 1 w: -1
# in
# context_word_idx: 1 1
# xx: (2, 1)
# context_word_pos: 2 w: 0
# context_word_pos: 3 w: 1
# in
# context_word_idx: 3 3
# xx: (2, 3)
# context_word_pos: 4 w: 2
#
# center_word_pos: 3
# range(-2, 3)
#
# context_word_pos: 1 w: -2
# in
# context_word_idx: 1 1
# xx: (3, 1)
# context_word_pos: 2 w: -1
# in
# context_word_idx: 2 2
# xx: (3, 2)
# context_word_pos: 3 w: 0
# context_word_pos: 4 w: 1
# context_word_pos: 5 w: 2
#
# sentence: ['she', 'is', 'a', 'queen']
# indices: [4, 1, 2, 5]
# range(0, 4)
#
# center_word_pos: 0
# range(-2, 3)
#
# context_word_pos: -2 w: -2
# context_word_pos: -1 w: -1
# context_word_pos: 0 w: 0
# context_word_pos: 1 w: 1
# in
# context_word_idx: 1 1
# xx: (4, 1)
# context_word_pos: 2 w: 2
# in
# context_word_idx: 2 2
# xx: (4, 2)
#
# center_word_pos: 1
# range(-2, 3)
#
# context_word_pos: -1 w: -2
# context_word_pos: 0 w: -1
# in
# context_word_idx: 4 4
# xx: (1, 4)
# context_word_pos: 1 w: 0
# context_word_pos: 2 w: 1
# in
# context_word_idx: 2 2
# xx: (1, 2)
# context_word_pos: 3 w: 2
# in
# context_word_idx: 5 5
# xx: (1, 5)
#
# center_word_pos: 2
# range(-2, 3)
#
# context_word_pos: 0 w: -2
# in
# context_word_idx: 4 4
# xx: (2, 4)
# context_word_pos: 1 w: -1
# in
# context_word_idx: 1 1
# xx: (2, 1)
# context_word_pos: 2 w: 0
# context_word_pos: 3 w: 1
# in
# context_word_idx: 5 5
# xx: (2, 5)
# context_word_pos: 4 w: 2
#
# center_word_pos: 3
# range(-2, 3)
#
# context_word_pos: 1 w: -2
# in
# context_word_idx: 1 1
# xx: (5, 1)
# context_word_pos: 2 w: -1
# in
# context_word_idx: 2 2
# xx: (5, 2)
# context_word_pos: 3 w: 0
# context_word_pos: 4 w: 1
# context_word_pos: 5 w: 2
#
# sentence: ['he', 'is', 'a', 'man']
# indices: [0, 1, 2, 6]
# range(0, 4)
#
# center_word_pos: 0
# range(-2, 3)
#
# context_word_pos: -2 w: -2
# context_word_pos: -1 w: -1
# context_word_pos: 0 w: 0
# context_word_pos: 1 w: 1
# in
# context_word_idx: 1 1
# xx: (0, 1)
# context_word_pos: 2 w: 2
# in
# context_word_idx: 2 2
# xx: (0, 2)
#
# center_word_pos: 1
# range(-2, 3)
#
# context_word_pos: -1 w: -2
# context_word_pos: 0 w: -1
# in
# context_word_idx: 0 0
# xx: (1, 0)
# context_word_pos: 1 w: 0
# context_word_pos: 2 w: 1
# in
# context_word_idx: 2 2
# xx: (1, 2)
# context_word_pos: 3 w: 2
# in
# context_word_idx: 6 6
# xx: (1, 6)
#
# center_word_pos: 2
# range(-2, 3)
#
# context_word_pos: 0 w: -2
# in
# context_word_idx: 0 0
# xx: (2, 0)
# context_word_pos: 1 w: -1
# in
# context_word_idx: 1 1
# xx: (2, 1)
# context_word_pos: 2 w: 0
# context_word_pos: 3 w: 1
# in
# context_word_idx: 6 6
# xx: (2, 6)
# context_word_pos: 4 w: 2
#
# center_word_pos: 3
# range(-2, 3)
#
# context_word_pos: 1 w: -2
# in
# context_word_idx: 1 1
# xx: (6, 1)
# context_word_pos: 2 w: -1
# in
# context_word_idx: 2 2
# xx: (6, 2)
# context_word_pos: 3 w: 0
# context_word_pos: 4 w: 1
# context_word_pos: 5 w: 2
#
# sentence: ['she', 'is', 'a', 'woman']
# indices: [4, 1, 2, 7]
# range(0, 4)
#
# center_word_pos: 0
# range(-2, 3)
#
# context_word_pos: -2 w: -2
# context_word_pos: -1 w: -1
# context_word_pos: 0 w: 0
# context_word_pos: 1 w: 1
# in
# context_word_idx: 1 1
# xx: (4, 1)
# context_word_pos: 2 w: 2
# in
# context_word_idx: 2 2
# xx: (4, 2)
#
# center_word_pos: 1
# range(-2, 3)
#
# context_word_pos: -1 w: -2
# context_word_pos: 0 w: -1
# in
# context_word_idx: 4 4
# xx: (1, 4)
# context_word_pos: 1 w: 0
# context_word_pos: 2 w: 1
# in
# context_word_idx: 2 2
# xx: (1, 2)
# context_word_pos: 3 w: 2
# in
# context_word_idx: 7 7
# xx: (1, 7)
#
# center_word_pos: 2
# range(-2, 3)
#
# context_word_pos: 0 w: -2
# in
# context_word_idx: 4 4
# xx: (2, 4)
# context_word_pos: 1 w: -1
# in
# context_word_idx: 1 1
# xx: (2, 1)
# context_word_pos: 2 w: 0
# context_word_pos: 3 w: 1
# in
# context_word_idx: 7 7
# xx: (2, 7)
# context_word_pos: 4 w: 2
#
# center_word_pos: 3
# range(-2, 3)
#
# context_word_pos: 1 w: -2
# in
# context_word_idx: 1 1
# xx: (7, 1)
# context_word_pos: 2 w: -1
# in
# context_word_idx: 2 2
# xx: (7, 2)
# context_word_pos: 3 w: 0
# context_word_pos: 4 w: 1
# context_word_pos: 5 w: 2
#
# sentence: ['warsaw', 'is', 'poland', 'capital']
# indices: [8, 1, 9, 10]
# range(0, 4)
#
# center_word_pos: 0
# range(-2, 3)
#
# context_word_pos: -2 w: -2
# context_word_pos: -1 w: -1
# context_word_pos: 0 w: 0
# context_word_pos: 1 w: 1
# in
# context_word_idx: 1 1
# xx: (8, 1)
# context_word_pos: 2 w: 2
# in
# context_word_idx: 9 9
# xx: (8, 9)
#
# center_word_pos: 1
# range(-2, 3)
#
# context_word_pos: -1 w: -2
# context_word_pos: 0 w: -1
# in
# context_word_idx: 8 8
# xx: (1, 8)
# context_word_pos: 1 w: 0
# context_word_pos: 2 w: 1
# in
# context_word_idx: 9 9
# xx: (1, 9)
# context_word_pos: 3 w: 2
# in
# context_word_idx: 10 10
# xx: (1, 10)
#
# center_word_pos: 2
# range(-2, 3)
#
# context_word_pos: 0 w: -2
# in
# context_word_idx: 8 8
# xx: (9, 8)
# context_word_pos: 1 w: -1
# in
# context_word_idx: 1 1
# xx: (9, 1)
# context_word_pos: 2 w: 0
# context_word_pos: 3 w: 1
# in
# context_word_idx: 10 10
# xx: (9, 10)
# context_word_pos: 4 w: 2
#
# center_word_pos: 3
# range(-2, 3)
#
# context_word_pos: 1 w: -2
# in
# context_word_idx: 1 1
# xx: (10, 1)
# context_word_pos: 2 w: -1
# in
# context_word_idx: 9 9
# xx: (10, 9)
# context_word_pos: 3 w: 0
# context_word_pos: 4 w: 1
# context_word_pos: 5 w: 2
#
# sentence: ['berlin', 'is', 'germany', 'capital']
# indices: [11, 1, 12, 10]
# range(0, 4)
#
# center_word_pos: 0
# range(-2, 3)
#
# context_word_pos: -2 w: -2
# context_word_pos: -1 w: -1
# context_word_pos: 0 w: 0
# context_word_pos: 1 w: 1
# in
# context_word_idx: 1 1
# xx: (11, 1)
# context_word_pos: 2 w: 2
# in
# context_word_idx: 12 12
# xx: (11, 12)
#
# center_word_pos: 1
# range(-2, 3)
#
# context_word_pos: -1 w: -2
# context_word_pos: 0 w: -1
# in
# context_word_idx: 11 11
# xx: (1, 11)
# context_word_pos: 1 w: 0
# context_word_pos: 2 w: 1
# in
# context_word_idx: 12 12
# xx: (1, 12)
# context_word_pos: 3 w: 2
# in
# context_word_idx: 10 10
# xx: (1, 10)
#
# center_word_pos: 2
# range(-2, 3)
#
# context_word_pos: 0 w: -2
# in
# context_word_idx: 11 11
# xx: (12, 11)
# context_word_pos: 1 w: -1
# in
# context_word_idx: 1 1
# xx: (12, 1)
# context_word_pos: 2 w: 0
# context_word_pos: 3 w: 1
# in
# context_word_idx: 10 10
# xx: (12, 10)
# context_word_pos: 4 w: 2
#
# center_word_pos: 3
# range(-2, 3)
#
# context_word_pos: 1 w: -2
# in
# context_word_idx: 1 1
# xx: (10, 1)
# context_word_pos: 2 w: -1
# in
# context_word_idx: 12 12
# xx: (10, 12)
# context_word_pos: 3 w: 0
# context_word_pos: 4 w: 1
# context_word_pos: 5 w: 2
#
# sentence: ['paris', 'is', 'france', 'capital']
# indices: [13, 1, 14, 10]
# range(0, 4)
#
# center_word_pos: 0
# range(-2, 3)
#
# context_word_pos: -2 w: -2
# context_word_pos: -1 w: -1
# context_word_pos: 0 w: 0
# context_word_pos: 1 w: 1
# in
# context_word_idx: 1 1
# xx: (13, 1)
# context_word_pos: 2 w: 2
# in
# context_word_idx: 14 14
# xx: (13, 14)
#
# center_word_pos: 1
# range(-2, 3)
#
# context_word_pos: -1 w: -2
# context_word_pos: 0 w: -1
# in
# context_word_idx: 13 13
# xx: (1, 13)
# context_word_pos: 1 w: 0
# context_word_pos: 2 w: 1
# in
# context_word_idx: 14 14
# xx: (1, 14)
# context_word_pos: 3 w: 2
# in
# context_word_idx: 10 10
# xx: (1, 10)
#
# center_word_pos: 2
# range(-2, 3)
#
# context_word_pos: 0 w: -2
# in
# context_word_idx: 13 13
# xx: (14, 13)
# context_word_pos: 1 w: -1
# in
# context_word_idx: 1 1
# xx: (14, 1)
# context_word_pos: 2 w: 0
# context_word_pos: 3 w: 1
# in
# context_word_idx: 10 10
# xx: (14, 10)
# context_word_pos: 4 w: 2
#
# center_word_pos: 3
# range(-2, 3)
#
# context_word_pos: 1 w: -2
# in
# context_word_idx: 1 1
# xx: (10, 1)
# context_word_pos: 2 w: -1
# in
# context_word_idx: 14 14
# xx: (10, 14)
# context_word_pos: 3 w: 0
# context_word_pos: 4 w: 1
# context_word_pos: 5 w: 2
#
# sentence: ['I', 'live', 'in', 'Jakarta,', 'Indonesia']
# indices: [15, 16, 17, 18, 19]
# range(0, 5)
#
# center_word_pos: 0
# range(-2, 3)
#
# context_word_pos: -2 w: -2
# context_word_pos: -1 w: -1
# context_word_pos: 0 w: 0
# context_word_pos: 1 w: 1
# in
# context_word_idx: 16 16
# xx: (15, 16)
# context_word_pos: 2 w: 2
# in
# context_word_idx: 17 17
# xx: (15, 17)
#
# center_word_pos: 1
# range(-2, 3)
#
# context_word_pos: -1 w: -2
# context_word_pos: 0 w: -1
# in
# context_word_idx: 15 15
# xx: (16, 15)
# context_word_pos: 1 w: 0
# context_word_pos: 2 w: 1
# in
# context_word_idx: 17 17
# xx: (16, 17)
# context_word_pos: 3 w: 2
# in
# context_word_idx: 18 18
# xx: (16, 18)
#
# center_word_pos: 2
# range(-2, 3)
#
# context_word_pos: 0 w: -2
# in
# context_word_idx: 15 15
# xx: (17, 15)
# context_word_pos: 1 w: -1
# in
# context_word_idx: 16 16
# xx: (17, 16)
# context_word_pos: 2 w: 0
# context_word_pos: 3 w: 1
# in
# context_word_idx: 18 18
# xx: (17, 18)
# context_word_pos: 4 w: 2
# in
# context_word_idx: 19 19
# xx: (17, 19)
#
# center_word_pos: 3
# range(-2, 3)
#
# context_word_pos: 1 w: -2
# in
# context_word_idx: 16 16
# xx: (18, 16)
# context_word_pos: 2 w: -1
# in
# context_word_idx: 17 17
# xx: (18, 17)
# context_word_pos: 3 w: 0
# context_word_pos: 4 w: 1
# in
# context_word_idx: 19 19
# xx: (18, 19)
# context_word_pos: 5 w: 2
#
# center_word_pos: 4
# range(-2, 3)
#
# context_word_pos: 2 w: -2
# in
# context_word_idx: 17 17
# xx: (19, 17)
# context_word_pos: 3 w: -1
# in
# context_word_idx: 18 18
# xx: (19, 18)
# context_word_pos: 4 w: 0
# context_word_pos: 5 w: 1
# context_word_pos: 6 w: 2

# %%
idx_pairs
# Out:
# array([[ 0,  1],
#        [ 0,  2],
#        [ 1,  0],
#        [ 1,  2],
#        [ 1,  3],
#        [ 2,  0],
#        [ 2,  1],
#        [ 2,  3],
#        [ 3,  1],
#        [ 3,  2],
#        [ 4,  1],
#        [ 4,  2],
#        [ 1,  4],
#        [ 1,  2],
#        [ 1,  5],
#        [ 2,  4],
#        [ 2,  1],
#        [ 2,  5],
#        [ 5,  1],
#        [ 5,  2],
#        [ 0,  1],
#        [ 0,  2],
#        [ 1,  0],
#        [ 1,  2],
#        [ 1,  6],
#        [ 2,  0],
#        [ 2,  1],
#        [ 2,  6],
#        [ 6,  1],
#        [ 6,  2],
#        [ 4,  1],
#        [ 4,  2],
#        [ 1,  4],
#        [ 1,  2],
#        [ 1,  7],
#        [ 2,  4],
#        [ 2,  1],
#        [ 2,  7],
#        [ 7,  1],
#        [ 7,  2],
#        [ 8,  1],
#        [ 8,  9],
#        [ 1,  8],
#        [ 1,  9],
#        [ 1, 10],
#        [ 9,  8],
#        [ 9,  1],
#        [ 9, 10],
#        [10,  1],
#        [10,  9],
#        [11,  1],
#        [11, 12],
#        [ 1, 11],
#        [ 1, 12],
#        [ 1, 10],
#        [12, 11],
#        [12,  1],
#        [12, 10],
#        [10,  1],
#        [10, 12],
#        [13,  1],
#        [13, 14],
#        [ 1, 13],
#        [ 1, 14],
#        [ 1, 10],
#        [14, 13],
#        [14,  1],
#        [14, 10],
#        [10,  1],
#        [10, 14],
#        [15, 16],
#        [15, 17],
#        [16, 15],
#        [16, 17],
#        [16, 18],
#        [17, 15],
#        [17, 16],
#        [17, 18],
#        [17, 19],
#        [18, 16],
#        [18, 17],
#        [18, 19],
#        [19, 17],
#        [19, 18]])

# %%
def get_input_layer(word_idx):
    x = torch.zeros(vocabulary_size).float()
    x[word_idx] = 1.0
    return x

# %%
embedding_dims = 5
W1 = Variable(torch.randn(embedding_dims, vocabulary_size).float(), requires_grad=True)
W2 = Variable(torch.randn(vocabulary_size, embedding_dims).float(), requires_grad=True)
num_epochs = 100
learning_rate = 0.001

for epo in range(num_epochs):
    loss_val = 0
    for data, target in idx_pairs:
        x = Variable(get_input_layer(data)).float()
        y_true = Variable(torch.from_numpy(np.array([target])).long())

        z1 = torch.matmul(W1, x)
        z2 = torch.matmul(W2, z1)
    
        log_softmax = F.log_softmax(z2, dim=0)

        loss = F.nll_loss(log_softmax.view(1,-1), y_true)
        loss_val += loss.data
        loss.backward()
        W1.data -= learning_rate * W1.grad.data
        W2.data -= learning_rate * W2.grad.data

        W1.grad.data.zero_()
        W2.grad.data.zero_()
    if epo % 10 == 0:    
        print(f'Loss at epo {epo}: {loss_val/len(idx_pairs)}')
# Out:
# Loss at epo 0: 5.2130126953125
# Loss at epo 10: 4.713010311126709
# Loss at epo 20: 4.363424777984619
# Loss at epo 30: 4.097565650939941
# Loss at epo 40: 3.8842580318450928
# Loss at epo 50: 3.706723213195801
# Loss at epo 60: 3.5549564361572266
# Loss at epo 70: 3.4225199222564697
# Loss at epo 80: 3.3050670623779297
# Loss at epo 90: 3.1995489597320557

# %%
from collections import Counter
import torch.nn as nn

# Let's say you have 2 sentences(lowercased, punctuations removed) :
sentences = "i am new to PyTorch i am having fun"

words = sentences.split(' ')
    
vocab = Counter(words) # create a dictionary
vocab = sorted(vocab, key=vocab.get, reverse=True)
vocab_size = len(vocab)

# map words to unique indices
word2idx = {word: ind for ind, word in enumerate(vocab)} 

# word2idx = {'i': 0, 'am': 1, 'new': 2, 'to': 3, 'pytorch': 4, 'having': 5, 'fun': 6}

encoded_sentences = [word2idx[word] for word in words]

# encoded_sentences = [0, 1, 2, 3, 4, 0, 1, 5, 6]

# let's say you want embedding dimension to be 3
emb_dim = 3

# %%
emb_layer = nn.Embedding(vocab_size, emb_dim)
word_vectors = emb_layer(torch.LongTensor(encoded_sentences))

# %%
emb_layer.weight.requires_grad
# Out:
# True
